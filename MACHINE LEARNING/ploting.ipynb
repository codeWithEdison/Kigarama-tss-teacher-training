# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd
music = pd.read_csv('vgsales.csv')
music
# Out:
#         Rank                                               Name Platform  \
# 0        259                                          Asteroids     2600
# 1        545                                    Missile Command     2600
# 2       1768                                            Kaboom!     2600
# 3       1971                                           Defender     2600
# 4       2671                                             Boxing     2600
# ...      ...                                                ...      ...
# 16319  16565                                       Mighty No. 9     XOne
# 16320  16572                                 Resident Evil 4 HD     XOne
# 16321  16573                      Farming 2017 - The Simulation      PS4
# 16322  16579                                  Rugby Challenge 3     XOne
# 16323  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
#
#        Year       Genre             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
music.shape
# Out:
# (16324, 11)

# %%
music.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16324.000000  16324.000000  16324.000000  16324.000000  16324.000000
# mean    8291.508270   2006.404251      0.265464      0.147581      0.078673
# std     4792.043734      5.826744      0.821658      0.508809      0.311584
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4135.750000   2003.000000      0.000000      0.000000      0.000000
# 50%     8293.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12439.250000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2016.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16324.000000  16324.000000
# mean       0.048334      0.540328
# std        0.189902      1.565860
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.480000
# ...

# %%
# for creating plots
import matplotlib.pyplot as plt
# for handling data
import pandas as pd
# read our csv into dataframe
music = pd.read_csv('music.csv')
#music

# %%
#1. scatter
# create a new figure with spefcied size whidt=8, height=6 inches
plt.figure(figsize=(5,4))
# x-axis = age, y_axix = genre
x= music['age']
y= music['genre']
plt.scatter(x,y)
plt.title('scatter plot : age vs music genre')
plt.xlabel('age of person')
plt.ylabel('music genre')
plt.show()

# %%
plt.figure(figsize=(4,3))

genre_counts = music['genre'].value_counts()
# genre_counts
x=genre_counts.index
y=genre_counts.values
plt.bar(x,y)
# Add labels and title
plt.xlabel('Music Genre')
plt.ylabel('Number of People')
plt.title('Bar Chart: Number of People by Genre')
plt.xticks(rotation=45)
plt.show()

# %%
# BOX PLOT
import seaborn as sns

plt.figure(figsize=(4,3))
sns.boxplot(x="genre", y="age", data=music)
# Add labels and title
plt.xlabel('Music Genre')
plt.ylabel('Age')
plt.title('Box Plot: Age Distribution by Genre')
# Rotate x-axis labels
plt.xticks(rotation=45)
plt.show()

# %%
#4. HEAT MAP
# convert genre to number plt
plt.figure(figsize=(4,3))
music['genre_number'] = pd.factorize(music['genre'])[0]
# create a correlatoin matrix
correlation = music[['age', 'gender', 'genre_number']].corr()
sns.heatmap(correlation, annot=True)
plt.show()
